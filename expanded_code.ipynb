# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#      Systolic Blood pressure  Diastolic Blood pressure  Age  Gender  Height  \
# 0                        120                        80   30       1     140
# 1                        145                        60   35       0     150
# 2                        115                        65   40       1     160
# 3                        100                        70   45       0     170
# 4                        105                        75   50       1     180
# ..                       ...                       ...  ...     ...     ...
# 195                      142                        55   70       1     173
# 196                      145                        40   75       0     174
# 197                      150                        45   80       0     176
# 198                      121                        43   85       1     178
# 199                      120                        80   90       1     180
#
# ...

# %%
df.Result.value_counts()
# Out:
# 0    50
# 1    50
# 3    40
# 4    30
# 2    30
# Name: Result, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
sns.countplot('Result',data=df)
plt.title()
plt.show()
# Out:
# C:\Users\windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X = df.drop('Result', axis='columns')

# %%
y = df['Result']
ycpy = df['Result']

# %%
y
# Out:
# 0      3
# 1      4
# 2      3
# 3      4
# 4      2
#       ..
# 195    1
# 196    0
# 197    1
# 198    0
# 199    0
# Name: Result, Length: 200, dtype: int64

# %%
ycpy
# Out:
# 0      3
# 1      4
# 2      3
# 3      4
# 4      2
#       ..
# 195    1
# 196    0
# 197    1
# 198    0
# 199    0
# Name: Result, Length: 200, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, test_size=0.1)

# %%
 X_test, y_test
# Out:
# (array([[100,  70,  45,   0, 170,  55,  15,  15,  60,   0,   0,  18,   0,
#            0],
#         [109,  79,  60,   1, 155,  70,  30,  30, 110,   1,   1,  21,   1,
#            1],
#         [125,  90,  85,   1, 156,  83,  55,  60, 200,   1,   0,  33,   1,
#            0],
#         [109,  79,  60,   1, 155,  70,  30,  30, 110,   1,   1,  21,   1,
#            1],
#         [121,  43,  85,   1, 178, 130,  90, 190, 231,   1,   1,  40,   1,
#            1],
#         [130, 100,  90,   0, 163,  85,  60,  70, 210,   0,   1,  34,   0,
#            1],
#         [109,  79,  60,   1, 155,  70,  30,  30, 110,   1,   1,  21,   1,
#            1],
#         [115,  65,  40,   1, 160,  50,  10,  10,  50,   1,   0,  17,   1,
#            0],
#         [105,  75,  50,   1, 180,  60,  20,  20,  70,   1,   0,  19,   1,
#            0],
#         [125,  90,  85,   1, 156,  83,  55,  60, 200,   1,   0,  33,   1,
#            0],
# ...

# %%
X_train
# Out:
# array([[105,  75,  50, ...,  19,   1,   0],
#        [118,  82,  75, ...,  30,   0,   1],
#        [115,  65,  40, ...,  17,   1,   0],
#        ...,
#        [135, 105,  55, ...,  35,   0,   0],
#        [105,  75,  50, ...,  19,   1,   0],
#        [140, 110,  60, ...,  36,   1,   1]], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 2, 2, 1, 2, 1, 3, 2, 0, 3, 4, 4, 3, 3, 3, 3, 1, 1, 2],
#       dtype=int64)

# %%
y_train
# Out:
# array([3, 3, 0, 3, 4, 3, 0, 3, 0, 3, 0, 3, 0, 2, 2, 1, 4, 1, 1, 3, 3, 2,
#        3, 3, 0, 3, 4, 2, 4, 0, 3, 0, 3, 0, 0, 1, 2, 1, 1, 3, 3, 3, 4, 1,
#        0, 4, 3, 1, 3, 0, 4, 2, 4, 0, 1, 4, 0, 0, 3, 0, 3, 3, 2, 1, 2, 4,
#        2, 4, 1, 0, 3, 1, 2, 0, 1, 4, 4, 3, 1, 1, 0, 2, 2, 3, 3, 1, 1, 0,
#        1, 2, 0, 0, 0, 0, 0, 4, 2, 3, 0, 4, 2, 1, 0, 2, 4, 2, 0, 1, 0, 0,
#        4, 1, 1, 0, 0, 1, 1, 1, 0, 2, 4, 3, 3, 1, 1, 1, 1, 1, 2, 0, 4, 1,
#        0, 1, 4, 1, 2, 0, 1, 0, 0, 4, 3, 1, 3, 3, 0, 0, 0, 0, 3, 4, 1, 0,
#        0, 2, 4, 2, 1, 1, 4, 0, 2, 2, 1, 1, 1, 4, 1, 3, 2, 1, 0, 1, 4, 0,
#        4, 1, 4, 1], dtype=int64)

# %%
X
# Out:
#      Systolic Blood pressure  Diastolic Blood pressure  Age  Gender  Height  \
# 0                        120                        80   30       1     140
# 1                        145                        60   35       0     150
# 2                        115                        65   40       1     160
# 3                        100                        70   45       0     170
# 4                        105                        75   50       1     180
# ..                       ...                       ...  ...     ...     ...
# 195                      142                        55   70       1     173
# 196                      145                        40   75       0     174
# 197                      150                        45   80       0     176
# 198                      121                        43   85       1     178
# 199                      120                        80   90       1     180
#
# ...

# %%
y
# Out:
# 0      3
# 1      4
# 2      3
# 3      4
# 4      2
#       ..
# 195    1
# 196    0
# 197    1
# 198    0
# 199    0
# Name: Result, Length: 200, dtype: int64

# %%
X_test
# Out:
# array([[130, 100,  90,   0, 163,  85,  60,  70, 210,   0,   1,  34,   0,
#           1],
#        [125,  90,  85,   1, 156,  83,  55,  60, 200,   1,   0,  33,   1,
#           0],
#        [130, 100,  90,   0, 163,  85,  60,  70, 210,   0,   1,  34,   0,
#           1],
#        [115,  65,  40,   1, 160,  50,  10,  10,  50,   1,   0,  17,   1,
#           0],
#        [121,  43,  85,   1, 178, 130,  90, 190, 231,   1,   1,  40,   1,
#           1],
#        [120,  80,  30,   1, 140,  40,   5,   5,  30,   1,   1,  15,   1,
#           1],
#        [150,  45,  80,   0, 176, 120,  85, 185, 235,   0,   0,  39,   0,
#           0],
#        [145,  40,  75,   0, 174, 110,  80, 120, 230,   0,   1,  38,   0,
#           1],
#        [105,  75,  50,   1, 180,  60,  20,  20,  70,   1,   0,  19,   1,
#           0],
#        [125,  90,  85,   1, 156,  83,  55,  60, 200,   1,   0,  33,   1,
#           0],
#        [125,  90,  85,   1, 156,  83,  55,  60, 200,   1,   0,  33,   1,
# ...

# %%
#-----------------------------Accuracy Calculation--------------------------------
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
accuracy= model.score(X_test, y_test)

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
accuracy= model.score(X_test, y_test)
accuracy
# Out:
# 1.0

# %%
#-----------------------------Predict value---------------------------------------
patient_data = input("Enter the patients data: ")
arr = patient_data.split(",")
arr = [int(x) for x in arr]  
predicted_output=model.predict([arr])
# Out:
# Enter the patients data: 140,110,60,1,171,95,70,90,220,1,1,36,1,1

# %%
arr
# Out:
# [140, 110, 60, 1, 171, 95, 70, 90, 220, 1, 1, 36, 1, 1]

# %%
predicted_output
# Out:
# array([0], dtype=int64)

# %%
array_value = predicted_output[0]
if array_value == 0:
    print('Heart health is in High risk')
elif array_value == 1:
    print('Heart health is Vulnerable')
elif array_value == 2:
    print('Heart health is Partially prone')
elif array_value == 3:
    print('Heart health is in low risk')    
elif array_value == 4:
    print('Heart health is good')    
else:
    print('Invalid data')

print('Accuracy level of this model:', accuracy)
# Out:
# Heart health is in High risk
# Accuracy level of this model: 1.0

# %%
df.dtypes
# Out:
# Systolic Blood pressure                            int64
# Diastolic Blood pressure                           int64
# Age                                                int64
# Gender                                             int64
# Height                                             int64
# Weight                                             int64
# High low-density lipoprotein (LDL) cholesterol     int64
# Low-density lipoprotein (LDL) cholesterol          int64
# Blood Glucose level                                int64
# Active smoking                                     int64
# Passive smoking                                    int64
# Obesity                                            int64
# Diet                                               int64
# Physical activity                                  int64
# Result                                             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Systolic Blood pressure                          200 non-null    int64
#  1   Diastolic Blood pressure                         200 non-null    int64
#  2   Age                                              200 non-null    int64
#  3   Gender                                           200 non-null    int64
#  4   Height                                           200 non-null    int64
#  5   Weight                                           200 non-null    int64
#  6   High low-density lipoprotein (LDL) cholesterol   200 non-null    int64
#  7   Low-density lipoprotein (LDL) cholesterol        200 non-null    int64
#  8   Blood Glucose level                              200 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Systolic Blood pressure  Diastolic Blood pressure         Age  \
# count               200.000000                 200.00000  200.000000
# mean                120.175000                  71.85000   64.750000
# std                  16.411614                  20.57533   17.896618
# min                  90.000000                  40.00000   30.000000
# 25%                 108.750000                  53.75000   53.750000
# 50%                 120.000000                  76.50000   67.500000
# 75%                 135.000000                  82.75000   80.000000
# max                 150.000000                 110.00000   90.000000
#
#            Gender      Height      Weight  \
# count  200.000000  200.000000  200.000000
# mean     0.550000  163.550000   82.400000
# std      0.498742   12.706486   26.986689
# min      0.000000  140.000000   40.000000
# 25%      0.000000  153.750000   63.750000
# 50%      1.000000  166.500000   79.500000
# 75%      1.000000  174.250000   96.250000
# ...

# %%
pd.crosstab(index = df["Active smoking"], columns = df["Passive smoking"])
# Out:
# Passive smoking   0   1
# Active smoking
# 0                40  50
# 1                50  60

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# Systolic Blood pressure                            0
# Diastolic Blood pressure                           0
# Age                                                0
# Gender                                             0
# Height                                             0
# Weight                                             0
# High low-density lipoprotein (LDL) cholesterol     0
# Low-density lipoprotein (LDL) cholesterol          0
# Blood Glucose level                                0
# Active smoking                                     0
# Passive smoking                                    0
# Obesity                                            0
# Diet                                               0
# Physical activity                                  0
# Result                                             0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

# %%
df.plot(kind='box', figsize=(10, 6))
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.plot(kind='line', figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
# Count the number of smokers and non-smokers
smoker_counts = df['Active smoking'].value_counts()

# Print the counts
print(smoker_counts)
# Out:
# 1    110
# 0     90
# Name: Active smoking, dtype: int64

# %%
# Count the number of smokers and non-smokers
smoker_counts = df['Active smoking'].value_counts()

# Plot the bar chart
smoker_counts.plot(kind='bar', figsize=(6, 6))
plt.xlabel('1-True,0-False')
plt.ylabel('Count')
plt.title('Distribution of Active Smokers,Passive Smoker,Gender,Diet,Physical Activity')
plt.xticks(rotation='horizontal')
plt.show()

# %%
# Plot the pie chart
smoker_counts.plot(kind='pie', figsize=(6, 6), autopct='%1.1f%%')
plt.ylabel('True')
plt.xlabel('False')
plt.title('Distribution of Active Smokers,Passive Smoker,Gender,Diet,Physical Activity')
plt.show()

# %%
passive_smoker_counts = df['Passive smoking'].value_counts()

# Print the counts
print(passive_smoker_counts)
# Out:
# 1    110
# 0     90
# Name: Passive smoking, dtype: int64

# %%
# Count the number of smokers and non-smokers
passive_smoker_counts = df['Passive smoking'].value_counts()

# Plot the bar chart
passive_smoker_counts.plot(kind='bar', figsize=(6, 6))
plt.xlabel('Passive smoking')
plt.ylabel('Count')
plt.title('Distribution of Passive Smokers')
plt.xticks(rotation='horizontal')
plt.show()

# %%
Physical_activity_counts = df['Physical activity'].value_counts()

# Print the counts
print(Physical_activity_counts)
# Out:
# 1    110
# 0     90
# Name: Physical activity, dtype: int64

# %%
# Plot the pie chart
Physical_activity_counts.plot(kind='pie', figsize=(6, 6), autopct='%1.1f%%')
plt.ylabel('')
plt.title('Distribution of Physically Active Patients')
plt.show()

# %%
Gender_counts = df['Gender'].value_counts()

# Print the counts
print(Physical_activity_counts)
# Out:
# 1    110
# 0     90
# Name: Physical activity, dtype: int64

# %%
Gender_counts.plot(kind='pie', figsize=(6, 6), autopct='%1.1f%%')
plt.ylabel('')
plt.title('Distribution of Gender ')
plt.show()

# %%
diet_counts=df['Diet'].value_counts()
diet_counts
# Out:
# 1    110
# 0     90
# Name: Diet, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.subplot()
# Out:
# <AxesSubplot:>
